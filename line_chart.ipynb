# %%
import seaborn as sns
import numpy as np
import pandas as pd

l, r = 0, 50
samp_batches = np.repeat(np.array(range(l, r+1, 5)), 4)
accuries = [
    70.4608, 70.4015, 70.3817, 70.3323,
    70.3520, 70.2130, 70.3421, 70.9355, 
    70.4410, 70.5003, 70.4212, 70.4410,
    70.6784, 70.5599, 70.2531, 70.7871,
    70.3421, 70.6586, 70.2828, 70.1246,
    70.2630, 70.4509, 70.7970, 71.3706,
    70.1147, 70.3521, 70.2729, 70.7971,
    70.6685, 70.6586, 70.2136, 70.3619,
    70.6191, 70.1938, 70.4806, 70.4806,
    70.7773, 70.3125, 70.2136, 70.5795,
    70.2532, 70.8465, 70.1642, 70.4015
]
data = pd.DataFrame({
    'samp batches': samp_batches,
    'accuracy (%)': accuries
})
sns.lineplot(data=data, x="samp batches", y="accuracy (%)", ci=20)
# Out:
# <AxesSubplot:xlabel='samp batches', ylabel='accuracy (%)'>

# %%
import seaborn as sns
import numpy as np
import pandas as pd

MAP_TS = [1] * 4 + [3] * 4 + [5] * 4 + [7] * 4 + [9] * 4
accuries = [
    72.1420, 72.6167, 72.4782, 72.2310,
    72.2409, 72.5574, 72.4585, 72.3794,
    71.9739, 72.7749, 72.6068, 72.2310,
    72.1618, 72.4980, 72.6661, 72.2508,
    72.2706, 72.5079, 72.4684, 72.1915
]
data = pd.DataFrame({
    'number of Teacher\'s layers' : MAP_TS,
    'accuracy (%)': accuries
})
print(data)
sns.lineplot(data=data, x="number of Teacher\'s layers", y="accuracy (%)", ci=20)
# Out:
#     number of Teacher's layers  accuracy (%)
# 0                            1       72.1420
# 1                            1       72.6167
# 2                            1       72.4782
# 3                            1       72.2310
# 4                            3       72.2409
# 5                            3       72.5574
# 6                            3       72.4585
# 7                            3       72.3794
# 8                            5       71.9739
# 9                            5       72.7749
# 10                           5       72.6068
# 11                           5       72.2310
# 12                           7       72.1618
# 13                           7       72.4980
# 14                           7       72.6661
# 15                           7       72.2508
# 16                           9       72.2706
# 17                           9       72.5079
# 18                           9       72.4684
# 19                           9       72.1915
# ...

# %%
import seaborn as sns
import numpy as np
import pandas as pd

l, r = 100, 1100
betas = np.repeat(np.array(range(l, r+1, 200)), 4)
accuries = [
    71.9442, 72.4288, 72.4090, 72.3794,
    72.1420, 72.3991, 72.2211, 72.2805,
    72.2409, 72.5574, 72.4585, 72.3794,
    72.2310, 72.7650, 72.6167, 72.5376,
    72.2706, 72.6562, 72.5969, 72.2607,
    72.2211, 72.6068, 72.2211, 72.3892
]
data = pd.DataFrame({
    'beta': betas,
    'accuracy (%)': accuries
})
sns.lineplot(data=data, x="beta", y="accuracy (%)", ci=95)
# Out:
# <AxesSubplot:xlabel='beta', ylabel='accuracy (%)'>
